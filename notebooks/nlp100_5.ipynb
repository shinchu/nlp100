# %% [markdown]
# # Chapter 5: 係り受け解析

# %% [markdown]
# 日本語Wikipediaの「人工知能」に関する記事からテキスト部分を抜き出したファイルが[ai.ja.zip](https://nlp100.github.io/data/ai.ja.zip)に収録されている．この文章をCaboChaやKNP等のツールを利用して係り受け解析を行い，その結果をai.ja.txt.parsedというファイルに保存せよ．このファイルを読み込み，以下の問に対応するプログラムを実装せよ．

# %%
# !brew tap uetchy/nlp
# !brew install knp jumanpp
# Out:
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# alsa-lib                   libhandy                   libxvmc
# arturo                     libice                     libxxf86dga
# asroute                    libmnl                     libxxf86vm
# bit-git                    libnetfilter-queue         matplotplusplus
# blaze                      libnfnetlink               ncspot
# box2d                      libpciaccess               nicotine-plus
# cloudformation-guard       libpthread-stubs           node@14
# commitizen                 libslirp                   openjdk@8
# cvs-fast-export            libsm                      or-tools
# device-mapper              libx11                     pdm
# dotnet                     libxau                     pickle
# envoy                      libxaw                     postgresql@12
# fleet-cli                  libxaw3d                   prometheus-cpp
# flit                       libxcb                     protoc-gen-go-grpc
# fnm                        libxcomposite              python@3.9
# font-util                  libxcursor                 rain
# foreman                    libxdamage                 rustscan
# fpart                      libxdmcp                   server-go
# gcalcli                    libxext                    shtools
# git-hound                  libxfixes                  structurizr-cli
# gitlint                    libxfont                   taskwarrior-tui
# gitql                      libxft                     tfsec
# googletest                 libxi                      trunk
# gost                       libxinerama                util-macros
# halide                     libxkbfile                 vint
# isort                      libxmu                     vivid
# ladspa-sdk                 libxpm                     webify
# leaf                       libxrandr                  x86_64-elf-gdb
# libaio                     libxrender                 xcb-proto
# libdmx                     libxres                    xdpyinfo
# libdrm                     libxscrnsaver              xorgproto
# libfontenc                 libxshmfence               xtrans
# libfs                      libxt                      zsh-you-should-use
# libfuse                    libxtst
# libgccjit                  libxv
# ==> Updated Formulae
# Updated 1621 formulae.
# ==> Renamed Formulae
# gst-validate -> gst-devtools
# ==> Deleted Formulae
# boost@1.55                 meson-internal             woboq_codebrowser
# boost@1.59                 mysql-connector-c++@1.1    xu4
# llvm@6                     scw@1
# ==> New Casks
# aio-creator-neo            gactions                   padloc
# ajour                      happymac                   perimeter81
# amazon-workdocs-drive      home-assistant             querypie
# anka-build-cloud-registry  hoststool                  recaf
# anka-virtualization        imarisviewer               ripme
# binance                    jetbrains-space            rotki
# boost-note                 kryoflux                   s3stat-setup
# cernbox                    loni-pipeline              solar2d
# classicftp                 lx-music                   spitfire-audio
# convert3dgui               mechvibes                  syncsettings
# copytranslator             medibangpaintpro           techsmith-capture
# craft                      messenger                  tenable-nessus-agent
# ddnet                      mic-drop                   tigerjython
# deltachat                  modern-csv                 time-to-leave
# displays                   mongodb-realm-studio       tunein
# ditto                      mtgaprotracker             waterfox-classic
# dropbox-passwords          multi                      xattred
# duoshao                    niftyman                   yggdrasil
# eudic-es                   nova                       yuque
# eul                        obs-ndi
# exifcleaner                opera-gx
# ==> Updated Casks
# visual-studio-code ✔                     menubar-countdown
# 010-editor                               menumeters
# 1password-cli                            merlin-project
# 4k-stogram                               meshlab
# 4k-video-downloader                      meshmixer
# 4k-video-to-mp3                          metabase
# 4k-youtube-to-mp3                        metashape
# 5kplayer                                 metasploit
# 8bitdo-ultimate-software                 mgba
# a-better-finder-attributes               mia-for-gmail
# a-better-finder-rename                   microblog
# ableton-live                             microsoft-auto-update
# ableton-live-intro                       microsoft-edge
# ableton-live-lite                        microsoft-excel
# ableton-live-standard                    microsoft-office
# ableton-live-suite                       microsoft-outlook
# abstract                                 microsoft-powerpoint
# accurics                                 microsoft-teams
# acorn                                    microsoft-word
# acquia-dev                               middle
# activedock                               miktex-console
# adguard                                  milanote
# adobe-acrobat-reader                     mindjet-mindmanager
# adobe-creative-cloud                     minecraft-server
# adobe-dng-converter                      minecraftpe
# adoptopenjdk                             minitube
# aerial                                   minizincide
# agenda                                   missive
# aircall                                  mkvtoolnix
# airdroid                                 mochi
# airflow                                  mockoon
# airfoil                                  mockuuups-studio
# airparrot                                modelio
# airtame                                  modulair
# airy                                     monero-wallet
# alfaview                                 moneymoney
# alfred                                   mongodb-compass
# all-in-one-messenger                     mongodb-compass-isolated-edition
# alt-tab                                  mongodb-compass-readonly
# altair-graphql-client                    monitorcontrol
# altserver                                mono-mdk
# amadine                                  moonlight
# amazon-chime                             mountain-duck
# amazon-music                             movist-pro
# amazon-workspaces                        mplabx-ide
# amethyst                                 mps
# ammonite                                 mqttx
# android-studio                           mullvadvpn
# angry-ip-scanner                         multipass
# anki                                     multitouch
# anonym                                   mumble
# anydesk                                  mumu
# anydo                                    musaicfm
# apache-couchdb                           musescore
# apparency                                musicbrainz-picard
# appcleaner                               musictube
# appcode                                  mweb
# appgate-sdp-client                       mycrypto
# appium                                   mymonero
# appstudio                                mysql-shell
# aptible                                  mysqlworkbench
# ark-desktop-wallet                       native-access
# arq                                      naver-whale
# artisan                                  navicat-data-modeler
# atext                                    navicat-data-modeler-essentials
# atom                                     navicat-for-mariadb
# audio-hijack                             navicat-for-mysql
# audiobook-builder                        navicat-for-oracle
# audirvana                                navicat-for-postgresql
# auristor-client                          navicat-for-sql-server
# autopkgr                                 navicat-for-sqlite
# avocode                                  navicat-premium
# aws-vault                                navicat-premium-essentials
# axe-edit-iii                             nbtexplorer
# axure-rp                                 ncar-ncl
# azure-data-studio                        neo4j
# backblaze                                neofinder
# badlion-client                           netbeans
# baidunetdisk                             netiquette
# balenaetcher                             netnewswire
# balsamiq-wireframes                      netron
# bankid                                   netxms-console
# banking-4                                nextcloud
# banktivity                               nomachine
# bartender                                nomachine-enterprise-client
# bbc-iplayer-downloads                    nordvpn
# bbedit                                   nordvpn-teams
# beekeeper-studio                         nosqlbooster-for-mongodb
# bettertouchtool                          noxappplayer
# beyond-compare                           nteract
# big-mean-folder-machine                  nuclear
# bilimini                                 numi
# bingpaper                                nvidia-geforce-now
# birdfont                                 obs
# biscuit                                  obs-virtualcam
# bisq                                     obsidian
# bitwarden                                obyte
# bitwig-studio                            ocenaudio
# blender                                  odrive
# blitz                                    olive
# blizz                                    omnidb
# blockblock                               omnigraffle
# blocs                                    omniplan
# blooo                                    one-switch
# blueharvest                              onedrive
# bluejeans                                onlyoffice
# bluestacks                               onyx
# bob                                      openaudible
# bonitastudiocommunity                    openbazaar
# bookmacster                              opencpn
# boom                                     openineditor-lite
# boom-3d                                  openinterminal
# boop                                     openinterminal-lite
# bootstrap-studio                         openphone
# box-drive                                openrct2
# boxcryptor                               openrefine
# brave-browser                            opensesame
# bria                                     openvpn-connect
# bricklink-studio                         openwebstart
# browserosaurus                           opera
# btcpayserver-vault                       oracle-jdk
# bunch                                    oracle-jdk-javadoc
# burp-suite                               orange
# busycal                                  origami-studio
# busycontacts                             origin
# butt                                     oscar
# c0re100-qbittorrent                      osmc
# cacher                                   osquery
# calibre                                  osxfuse
# camo-studio                              outline-manager
# camtasia                                 overdrive-media-console
# camunda-modeler                          p4v
# caprine                                  packetproxy
# carbon-copy-cloner                       pagico
# cardhop                                  paperspace
# catlight                                 parallels
# ccleaner                                 parallels-client
# cctalk                                   parallels-toolbox
# cellprofiler                             parallels-virtualization-sdk
# chatty                                   pastebot
# checkra1n                                paw
# chef-workstation                         pcoipclient
# chemdoodle                               pd
# chiaki                                   pd-l2ork
# chirp                                    pdf-expert
# chrome-remote-desktop-host               pdfelement
# chromedriver                             pdfpen
# chromium                                 pdfpenpro
# chronosync                               pdfsam-basic
# chronycontrol                            permute
# cisco-jabber                             pflists
# cisdem-document-reader                   pgadmin4
# clamxav                                  phocus
# clash-for-windows                        photoninja
# cleanmymac                               photosweeper-x
# cleanshot                                phpstorm
# clickup                                  piezo
# clion                                    pixelsnap
# clip-studio-paint                        plex
# clipgrab                                 plex-media-server
# clockify                                 plexamp
# cloudflare-warp                          plotdigitizer
# cloudytabs                               pocket-casts
# cmake                                    podolski
# coconutbattery                           polar-bookshelf
# coda                                     popclip
# codeexpander                             popo
# codekit                                  portfolioperformance
# commander-one                            porting-kit
# cookie                                   postbox
# copyq                                    posterazor
# corretto                                 postgres
# coteditor                                postman
# cozy-drive                               power-manager
# craftmanager                             pppc-utility
# crossover                                praat
# customshortcuts                          preform
# cyberduck                                prepros
# cycling74-max                            presentation
# cytoscape                                prezi-next
# daedalus-mainnet                         proclaim
# dangerzone                               profind
# dash                                     progressive-downloader
# dash-dash                                propresenter
# dashcam-viewer                           protonmail-bridge
# dashlane                                 protonmail-unofficial
# data-rescue                              protonvpn
# data-science-studio                      protopie
# datadog-agent                            prowritingaid
# datagrip                                 proxyman
# datovka                                  psychopy
# db-browser-for-sqlite                    publii
# dbeaver-community                        publish-or-perish
# dbeaver-enterprise                       pulse-sms
# dbschema                                 pycharm
# dbvisualizer                             pycharm-ce
# dcp-o-matic                              pycharm-ce-with-anaconda-plugin
# dcp-o-matic-batch-converter              pycharm-edu
# dcp-o-matic-encode-server                pycharm-with-anaconda-plugin
# dcp-o-matic-kdm-creator                  pyfa
# dcp-o-matic-player                       pyzo
# dcv-viewer                               qbittorrent
# debookee                                 qfinder-pro
# deeper                                   qgis
# deepl                                    qiyimedia
# deezer                                   qlab
# devolo-cockpit                           qlc-plus
# dexed                                    qobuz
# difffork                                 qownnotes
# dingtalk                                 qq
# disk-drill                               qqlive
# diskcatalogmaker                         qqmusic
# djay-pro                                 qt-creator
# dmm-player                               qt-design-studio
# docker                                   qtum
# doly                                     quail
# dosbox-x                                 quaternion
# dotnet                                   querious
# dotnet-sdk                               quickbooks
# downie                                   quicken
# drama                                    quickhash
# drawio                                   quip
# drivedx                                  qutebrowser
# drivethrurpg                             qview
# dropbox                                  qxmledit
# dropdmg                                  qyooo
# dropshare                                r
# eaglefiler                               raiderio
# easy-move-plus-resize                    rambox
# easyeda                                  raven-reader
# eclipse-cpp                              razorsql
# eclipse-dsl                              react-native-debugger
# eclipse-ide                              react-studio
# eclipse-installer                        reaper
# eclipse-java                             rectangle
# eclipse-javascript                       redisinsight
# eclipse-jee                              refined-github-safari
# eclipse-modeling                         regexhibit
# eclipse-php                              rekordbox
# eclipse-platform                         remember-the-milk
# eclipse-rcp                              remote-desktop-manager
# eclipse-testing                          remote-desktop-manager-free
# eiskaltdcpp                              remotix-agent
# electerm                                 removebg
# electron                                 renamer
# electron-cash                            rescuetime
# electron-fiddle                          responsively
# electrum                                 reunion
# electrumsv                               rhinoceros
# element                                  rider
# elmedia-player                           ridibooks
# eloston-chromium                         rightfont
# elpass                                   ringcentral
# emby-server                              ringcentral-classic
# emclient                                 ringcentral-meetings
# eme                                      robo-3t
# endurance                                rocket-chat
# enpass                                   rocks-n-diamonds
# epic-games                               rotato
# epichrome                                royal-tsx
# eqmac                                    rstudio
# eset-cyber-security-pro                  rsyncosx
# eudic                                    rubymine
# eve-launcher                             runway
# evernote                                 sabnzbd
# exodus                                   santa
# expandrive                               sapmachine-jdk
# expressvpn                               sauce-connect
# extraterm                                scihubeva
# ezip                                     scilab
# fantastical                              scratch
# farrago                                  screen
# fastrawviewer                            screenflick
# fastscripts                              scrooo
# favro                                    scrutiny
# feed-the-beast                           scummvm
# feishu                                   seadrive
# fellow                                   seafile-client
# file-juicer                              seamonkey
# filebot                                  second-life-viewer
# fing                                     securesafe
# firefox                                  securityspy
# fission                                  segger-embedded-studio-for-arm
# fitbit-os-simulator                      sejda-pdf
# fl-studio                                selfcontrol
# flash-npapi                              sequel-ace
# flash-player                             session
# flash-player-debugger                    session-manager-plugin
# flash-player-debugger-npapi              sessionrestore
# flash-player-debugger-ppapi              sf-symbols
# flash-ppapi                              sharepod
# fldigi                                   sherlock
# flightgear                               shift
# flipper                                  shotcut
# flock                                    showyedge
# flutter                                  sidenotes
# fly                                      sidequest
# fme                                      signal
# folding-at-home                          silentknight
# folx                                     sim-genie
# fontexplorer-x-pro                       simplenote
# fork                                     simply-fortran
# foxitreader                              sip
# foxmail                                  sipgate-softphone
# fractal-bot                              sirimote
# framer                                   sitebulb
# freac                                    sizzy
# freecad                                  sketch
# freedom                                  skim
# freeorion                                skybox
# freeplane                                skype
# freetube                                 skype-for-business
# freeyourmusic                            slack
# frhelper                                 slicer
# fritzing                                 slite
# front                                    smartgit
# fsnotes                                  smartsvn
# futuniuniu                               snagit
# ganache                                  snipaste
# garagebuy                                snowflake-snowsql
# garagesale                               softmaker-freeoffice
# gdlauncher                               softorino-youtube-converter
# geany                                    soulver
# geekbench                                soundsource
# gemini                                   spamsieve
# geneious-prime                           spatterlight
# genymotion                               spires
# geogebra                                 splashtop-business
# geph                                     splashtop-streamer
# get-backup-pro                           splayer
# get-iplayer-automator                    splice
# ghost-browser                            springtoolsuite
# gifox                                    sqlectron
# gingko                                   sqleditor
# gisto                                    sqlpro-for-mssql
# gitfinder                                sqlpro-for-mysql
# github                                   sqlpro-for-sqlite
# gitkraken                                sqlpro-studio
# gloomhaven-helper                        stack
# gns3                                     stack-stack
# gnucash                                  standard-notes
# gobdokumente                             staruml
# godot                                    stats
# gog-galaxy                               steermouse
# goland                                   stella
# golly                                    stellarium
# goodsync                                 stoplight-studio
# google-chat                              strawberry
# google-chrome                            streamlabs-obs
# google-featured-photos                   stremio
# gpg-suite-pinentry                       stretchly
# gpower                                   studio-3t
# gpxsee                                   subler
# grandtotal                               sublime-merge
# graphicconverter                         subnetcalc
# grids                                    subsurface
# gtkwave                                  suitcase-fusion
# hackintool                               sunloginclient
# hammerspoon                              superproductivity
# hands-off                                surge-synthesizer
# hbuilderx                                suspicious-package
# helium                                   swift-publisher
# hey                                      swiftformat-for-xcode
# historyhound                             swiftstack-client
# hookshot                                 swifty
# hotswitch                                swinsian
# houdahspot                               switchhosts
# hstracker                                syncovery
# http-toolkit                             syncplay
# hydrogen                                 syncroom
# ibackup-viewer                           syncthing
# ibm-cloud-cli                            synfigstudio
# icab                                     syntax-highlight
# icanhazshortcut                          tableau
# icefloor                                 tableau-prep
# icollections                             tableau-public
# iconjar                                  tableau-reader
# icons8                                   tableplus
# icq                                      tagspaces
# iexplorer                                tales-of-majeyal
# iglance                                  tap-forms
# iina                                     taskade
# iina-plus                                tastyworks
# ilok-license-manager                     td-agent
# imazing                                  teamdrive
# imgotv                                   teamviewer
# imitone                                  telavox-flow
# inkdrop                                  telegram
# insomnia                                 telegram-desktop
# insomnia-designer                        tempo
# insync                                   tencent-lemon
# integrity                                tencent-meeting
# intel-haxm                               termius
# intel-power-gadget                       texpad
# intellij-idea                            textadept
# intellij-idea-ce                         tg-pro
# intune-company-portal                    the-battle-for-wesnoth
# invisor-lite                             thebrain
# ipe                                      thedesk
# ipepresenter                             thor
# ipfs                                     thorium
# ipvanish-vpn                             thunderbird
# iridient-developer                       tibco-jaspersoft-studio
# iris                                     ticktick
# ishowu-instant                           tidepool-uploader
# istat-menus                              tiger-trade
# isteg                                    timecamp
# itsycal                                  timelane
# itubedownloader                          timemator
# ivpn                                     timer
# izip                                     timeular
# jabt-flow                                tinderbox
# jalbum                                   tinkerwell
# jalview                                  tinymediamanager
# jamf-migrator                            tla-plus-toolbox
# jami                                     toggl-track
# jamulus                                  tongbu
# jasp                                     topcat
# jasper                                   tor-browser
# jaxx-liberty                             torguard
# jbrowse                                  tortoisehg
# jclasslib-bytecode-viewer                touchdesigner
# jedit-omega                              tracks-live
# jgrasp                                   trader-workstation
# jitouch                                  trailer
# jitsi-meet                               transmission
# joplin                                   transmit
# josm                                     transnomino
# juicebar                                 tresorit
# julia                                    tribler
# jumpcut                                  trilium-notes
# jumpshare                                triplecheese
# kactus                                   tripmode
# karabiner-elements                       tropy
# katalon-studio                           tunnelbear
# kdiff3                                   tuple
# keep-it                                  turbo-boost-switcher
# keepassxc                                tuxera-ntfs
# keeweb                                   tweetbot
# kern                                     tweeten
# kext-updater                             twist
# keycue                                   typinator
# keymanager                               typora
# keysmith                                 ubersicht
# keystore-explorer                        ueli
# kicad                                    ultimate
# kid3                                     uninstallpkg
# kindle                                   unity
# kite                                     unity-android-support-for-editor
# kitematic                                unity-download-assistant
# kitty                                    unity-hub
# klayout                                  unity-ios-support-for-editor
# klokki                                   unity-lumin-support-for-editor
# knime                                    unity-webgl-support-for-editor
# knotes                                   unity-windows-support-for-editor
# kodi                                     upic
# koodo-reader                             upwork
# krisp                                    use-engine
# krita                                    usenapp
# kubernetic                               utools
# kui                                      uu-booster
# lando                                    vagrant-vmware-utility
# lark                                     vallum
# lastpass                                 vassal
# latexdraw                                vellum
# latexit                                  vesta
# launchbar                                videostream
# lazpaint                                 vidrio
# lbry                                     vienna
# ledger-live                              virtualbox
# lehreroffice                             virtualbox-extension-pack
# lens                                     virtualhostx
# libreoffice                              visicut
# libreoffice-language-pack                visit
# librepcb                                 visual-paradigm
# lifesize                                 visual-paradigm-ce
# lightproxy                               visual-studio
# lightworks                               vitamin-r
# line-bot-designer                        vivaldi
# linear-linear                            vivi
# linein                                   vmware-fusion
# lingo                                    vorta
# linphone                                 vrew
# listen1                                  vscodium
# little-snitch                            vuescan
# loaf                                     waltr
# local                                    wasabi-wallet
# localdev                                 waterfox-current
# logdna-agent                             waves-central
# logisim-evolution                        weakauras-companion
# logitech-presentation                    webcatalog
# logos                                    webex-teams
# loom                                     webstorm
# loopback                                 webviewscreensaver
# lrtimelapse                              wechat
# ltspice                                  wechatwebdevtools
# lyricsx                                  wechatwork
# m3unify                                  whale
# macbreakz                                whalebird
# maccy                                    whatroute
# macdive                                  whatsapp
# macgamestore                             whichspace
# macjournal                               wickrme
# macpilot                                 wingpersonal
# macs-fan-control                         wire
# mactex                                   wireshark
# mactex-no-gui                            wireshark-chmodbpf
# mactracker                               wondershare-filmora
# macupdater                               wondershare-uniconverter
# macvim                                   wordpresscom
# macx-dvd-ripper-pro                      workflowy
# mailbutler                               wormhole
# makemkv                                  wpsoffice
# maltego                                  wrike
# malus                                    wwdc
# malwarebytes                             x-swiftformat
# mamp                                     xamarin-ios
# manictime                                ximalaya
# marathon                                 xlink-kai
# markdown-service-tools                   xmplify
# mars                                     yacreader
# marsedit                                 yam-display
# marvel                                   yandex-disk
# marvin                                   yate
# master-password                          yed
# master-pdf-editor                        yep
# masterway-note                           yinxiangbiji
# mathpix-snipping-tool                    youdaodict
# matterhorn                               youdaonote
# mattermost                               youku
# max                                      ytmdesktop-youtube-music
# mcbopomofo                               zalo
# mcgimp                                   zenmap
# mcreator                                 zeplin
# media-center                             zoc
# mediainfo                                zoolz
# meetingbar                               zoom-for-it-admins
# megasync                                 zoomus
# melodics                                 zotero
# memory                                   zulu
# mendeley-reference-manager
# ==> Deleted Casks
# anka-flow           delta               megahertz-knotes    waterfox
# brogue              hand-mirror         odio                xact
# chicken             java                realm-studio
# coronasdk           jing                ring
# daedalus            levelator           station
#
# ==> Tapping uetchy/nlp
# Cloning into '/usr/local/Homebrew/Library/Taps/uetchy/homebrew-nlp'...
# remote: Enumerating objects: 175, done.
# remote: Total 175 (delta 0), reused 0 (delta 0), pack-reused 175
# Receiving objects: 100% (175/175), 21.91 KiB | 270.00 KiB/s, done.
# Resolving deltas: 100% (62/62), done.
# Tapped 8 formulae (33 files, 55.8KB).
# Updating Homebrew...
# ==> Installing knp from uetchy/nlp
# ==> Downloading https://homebrew.bintray.com/bottles/juman-7.01.mojave.bottle.ta
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/36bae86cd2b24c5b3b4e7
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/tinycdb-0.78.mojave.bottle.
# ######################################################################## 100.0%
# ==> Downloading http://nlp.ist.i.kyoto-u.ac.jp/DLcounter/lime.cgi?down=http://nl
# ==> Downloading from http://nlp.ist.i.kyoto-u.ac.jp/nl-resource/knp/knp-4.19.tar
# ######################################################################## 100.0%
# ==> Installing dependencies for uetchy/nlp/knp: juman and tinycdb
# ==> Installing uetchy/nlp/knp dependency: juman
# ==> Pouring juman-7.01.mojave.bottle.tar.gz
# 🍺  /usr/local/Cellar/juman/7.01: 31 files, 31.3MB
# ==> Installing uetchy/nlp/knp dependency: tinycdb
# ==> Pouring tinycdb-0.78.mojave.bottle.tar.gz
# 🍺  /usr/local/Cellar/tinycdb/0.78: 10 files, 84.6KB
# ==> Installing uetchy/nlp/knp
# ==> ./configure --prefix=/usr/local/Cellar/knp/4.19 --with-juman-prefix=/usr/loc
# ==> make install
# 🍺  /usr/local/Cellar/knp/4.19: 71 files, 3GB, built in 13 minutes 40 seconds
# ==> `brew cleanup` has not been run in 30 days, running now...
# Removing: /Users/shu/Library/Caches/Homebrew/autoconf--2.69.mojave.bottle.4.tar.gz... (874.7KB)
# Removing: /Users/shu/Library/Caches/Homebrew/bash-git-prompt--2.7.1.tar.gz... (49.7KB)
# Removing: /Users/shu/Library/Caches/Homebrew/docbook--5.1_1.mojave.bottle.tar.gz... (1.3MB)
# Removing: /Users/shu/Library/Caches/Homebrew/docbook-xsl--1.79.2_1.mojave.bottle.tar.gz... (46.4MB)
# Removing: /Users/shu/Library/Caches/Homebrew/exa--0.9.0.mojave.bottle.tar.gz... (639.7KB)
# Removing: /Users/shu/Library/Caches/Homebrew/gdbm--1.18.1.mojave.bottle.1.tar.gz... (196.2KB)
# Removing: /Users/shu/Library/Caches/Homebrew/gettext--0.20.2_1.mojave.bottle.tar.gz... (8.4MB)
# Removing: /Users/shu/Library/Caches/Homebrew/ghostscript--9.52.mojave.bottle.tar.gz... (32.4MB)
# Removing: /Users/shu/Library/Caches/Homebrew/icu4c--67.1.mojave.bottle.tar.gz... (26.8MB)
# Removing: /Users/shu/Library/Caches/Homebrew/jpeg--9d.mojave.bottle.tar.gz... (308.5KB)
# Removing: /Users/shu/Library/Caches/Homebrew/libde265--1.0.5.mojave.bottle.tar.gz... (705.9KB)
# Removing: /Users/shu/Library/Caches/Homebrew/libffi--3.3.mojave.bottle.tar.gz... (159.6KB)
# Removing: /Users/shu/Library/Caches/Homebrew/libidn2--2.3.0.mojave.bottle.tar.gz... (233.3KB)
# Removing: /Users/shu/Library/Caches/Homebrew/libomp--10.0.0.mojave.bottle.tar.gz... (460.7KB)
# Removing: /Users/shu/Library/Caches/Homebrew/libpng--1.6.37.mojave.bottle.tar.gz... (442.2KB)
# Removing: /Users/shu/Library/Caches/Homebrew/libtermkey--0.22.mojave.bottle.tar.gz... (53.6KB)
# Removing: /Users/shu/Library/Caches/Homebrew/libtiff--4.1.0.mojave.bottle.tar.gz... (1.1MB)
# Removing: /Users/shu/Library/Caches/Homebrew/libtool--2.4.6_1.mojave.bottle.tar.gz... (1003.4KB)
# Removing: /Users/shu/Library/Caches/Homebrew/libunistring--0.9.10.mojave.bottle.tar.gz... (1.4MB)
# Removing: /Users/shu/Library/Caches/Homebrew/libvterm--0.1.3.mojave.bottle.tar.gz... (67.1KB)
# Removing: /Users/shu/Library/Caches/Homebrew/luajit--2.0.5.mojave.bottle.3.tar.gz... (889.8KB)
# Removing: /Users/shu/Library/Caches/Homebrew/mecab--0.996.mojave.bottle.3.tar.gz... (847.5KB)
# Removing: /Users/shu/Library/Caches/Homebrew/mecab-ipadic--2.7.0-20070801.mojave.bottle.tar.gz... (12.9MB)
# Removing: /Users/shu/Library/Caches/Homebrew/micro--2.0.6.mojave.bottle.tar.gz... (5MB)
# Removing: /Users/shu/Library/Caches/Homebrew/ncurses--6.2.mojave.bottle.tar.gz... (2.3MB)
# Removing: /Users/shu/Library/Caches/Homebrew/neovim--0.4.3.mojave.bottle.tar.gz... (6.3MB)
# Removing: /Users/shu/Library/Caches/Homebrew/nodebrew--1.0.1.tar.gz... (26.3KB)
# Removing: /Users/shu/Library/Caches/Homebrew/openjpeg--2.3.1.mojave.bottle.tar.gz... (2MB)
# Removing: /Users/shu/Library/Caches/Homebrew/openssl@1.1--1.1.1g.mojave.bottle.tar.gz... (5.3MB)
# Removing: /Users/shu/Library/Caches/Homebrew/pcre--8.44.mojave.bottle.tar.gz... (1.8MB)
# Removing: /Users/shu/Library/Caches/Homebrew/pkg-config--0.29.2_3.mojave.bottle.tar.gz... (234.2KB)
# Removing: /Users/shu/Library/Caches/Homebrew/poetry--1.0.9.mojave.bottle.tar.gz... (3.8MB)
# Removing: /Users/shu/Library/Caches/Homebrew/readline--8.0.4.mojave.bottle.tar.gz... (517.6KB)
# Removing: /Users/shu/Library/Caches/Homebrew/reattach-to-user-namespace--2.8.mojave.bottle.tar.gz... (12.2KB)
# Removing: /Users/shu/Library/Caches/Homebrew/shared-mime-info--2.0.mojave.bottle.tar.gz... (1MB)
# Removing: /Users/shu/Library/Caches/Homebrew/unibilium--2.0.0.mojave.bottle.tar.gz... (136.8KB)
# Removing: /Users/shu/Library/Caches/Homebrew/utf8proc--2.5.0.mojave.bottle.tar.gz... (152.7KB)
# Removing: /Users/shu/Library/Caches/Homebrew/webp--1.1.0.mojave.bottle.tar.gz... (858.3KB)
# Removing: /Users/shu/Library/Caches/Homebrew/wget--1.20.3_2.mojave.bottle.tar.gz... (1.4MB)
# Removing: /Users/shu/Library/Caches/Homebrew/xmlto--0.0.28.mojave.bottle.1.tar.gz... (41.3KB)
# Removing: /Users/shu/Library/Caches/Homebrew/xz--5.2.5.mojave.bottle.tar.gz... (386.8KB)
# Removing: /Users/shu/Library/Caches/Homebrew/yarn--1.22.4.tar.gz... (1.2MB)
# Removing: /Users/shu/Library/Caches/Homebrew/z--1.9.tar.gz... (5.8KB)
# Removing: /Users/shu/Library/Caches/Homebrew/portable-ruby-2.6.3_1.yosemite.bottle.tar.gz... (9.1MB)
# Removing: /Users/shu/Library/Caches/Homebrew/portable-ruby-2.6.3_2.yosemite.bottle.tar.gz... (9.1MB)
# Removing: /Users/shu/Library/Caches/Homebrew/portable-ruby-2.6.3.mavericks.bottle.tar.gz... (9.0MB)
# Removing: /Users/shu/Library/Caches/Homebrew/Cask/google-cloud-sdk--latest.tar.gz... (25.2MB)
# Removing: /Users/shu/Library/Logs/Homebrew/micro... (64B)
# Removing: /Users/shu/Library/Logs/Homebrew/mecab-ipadic... (64B)
# Removing: /Users/shu/Library/Logs/Homebrew/mecab... (64B)
# Pruned 1 symbolic links from /usr/local
# ==> Downloading https://homebrew.bintray.com/bottles/boost-1.74.0.mojave.bottle.
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/5e2e4d620e783c93a9f44
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/gperftools-2.8.mojave.bottl
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/efcfaff363bbb0508a50d
# ######################################################################## 100.0%
# ==> Downloading https://homebrew.bintray.com/bottles/jumanpp-1.02.mojave.bottle.
# ==> Downloading from https://d29vzk4ow07wi7.cloudfront.net/248e639859582dcf3613e
# ######################################################################## 100.0%
# ==> Installing dependencies for jumanpp: boost and gperftools
# ==> Installing jumanpp dependency: boost
# ==> Pouring boost-1.74.0.mojave.bottle.tar.gz
# 🍺  /usr/local/Cellar/boost/1.74.0: 14,695 files, 603.6MB
# ==> Installing jumanpp dependency: gperftools
# ==> Pouring gperftools-2.8.mojave.bottle.tar.gz
# 🍺  /usr/local/Cellar/gperftools/2.8: 104 files, 4.6MB
# ==> Installing jumanpp
# ==> Pouring jumanpp-1.02.mojave.bottle.tar.gz
# 🍺  /usr/local/Cellar/jumanpp/1.02: 34 files, 1.8GB
